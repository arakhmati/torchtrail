# %%
import torch
import torchtrail

# %%
with torchtrail.trace():
    tensor = torch.rand(1, 64)
    tensors = torch.split(tensor, split_size_or_sections=32, dim=1)
    tensors = tuple(torch.exp(tensor) for tensor in tensors)
torchtrail.visualize(tensors)
