# %%
import torch
import torchtrail

# %%
with torchtrail.trace():
    input_tensor = torch.rand(1, 64)
    output_tensor = torch.exp(input_tensor)
torchtrail.visualize(output_tensor)

# %%
torchtrail.visualize(output_tensor, verbose=True)

# %%
print(torchtrail.codegen(output_tensor))
# Out:
# def main():
#     variable_0 = torch.rand(1, 64)    # shapes: (1, 64), dtypes: torch.float32; duration: 340.9 µs
#     variable_1 = torch.exp(variable_0)    # shapes: (1, 64), dtypes: torch.float32; duration: 36.0 µs
#     return variable_1
